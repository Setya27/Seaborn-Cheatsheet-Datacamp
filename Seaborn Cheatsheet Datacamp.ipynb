# %% [markdown]
# #  Seaborn Cheatsheet from datacamp

# %%
# %config Completer.use_jedi = False

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
sns.set_style('whitegrid')
sns.set()

# %%
# Load dataset
tips = sns.load_dataset('tips')
titanic = sns.load_dataset('titanic')
iris = sns.load_dataset('iris')
data = pd.DataFrame({'x': np.arange(1,101), 'y': np.random.normal(0,4,100)})

# %%
# Function for Data info
def data_info (df):
    column, nunique, null, null_p, dtype  = [],[],[],[],[]
    for col in df.columns:
        column.append(col)
        nunique.append(df[col].nunique())
        null.append(df[col].isnull().sum())
        null_p.append((df[col].isnull().sum()/df[col].count())*100)
        dtype.append(df[col].dtype)
    return pd.DataFrame({'Column': column, 'N-unique': nunique, 'Null': null, 'Null Percent': null_p,'Dtype': dtype})

# %%
data_info(tips)
# Out:
#        Column  N-unique  Null  Null Percent     Dtype
# 0  total_bill       229     0           0.0   float64
# 1         tip       123     0           0.0   float64
# 2         sex         2     0           0.0  category
# 3      smoker         2     0           0.0  category
# 4         day         4     0           0.0  category
# 5        time         2     0           0.0  category
# 6        size         6     0           0.0     int64

# %%
data_info(iris)
# Out:
#          Column  N-unique  Null  Null Percent    Dtype
# 0  sepal_length        35     0           0.0  float64
# 1   sepal_width        23     0           0.0  float64
# 2  petal_length        43     0           0.0  float64
# 3   petal_width        22     0           0.0  float64
# 4       species         3     0           0.0   object

# %%
data_info(titanic)
# Out:
#          Column  N-unique  Null  Null Percent     Dtype
# 0      survived         2     0      0.000000     int64
# 1        pclass         3     0      0.000000     int64
# 2           sex         2     0      0.000000    object
# 3           age        88   177     24.789916   float64
# 4         sibsp         7     0      0.000000     int64
# 5         parch         7     0      0.000000     int64
# 6          fare       248     0      0.000000   float64
# 7      embarked         3     2      0.224972    object
# 8         class         3     0      0.000000  category
# 9           who         3     0      0.000000    object
# 10   adult_male         2     0      0.000000      bool
# 11         deck         7   688    338.916256  category
# 12  embark_town         3     2      0.224972    object
# 13        alive         2     0      0.000000    object
# 14        alone         2     0      0.000000      bool

# %% [markdown]
# ### Axis Grids

# %%
a = sns.FacetGrid(data=titanic, col='survived', row='sex')
a = a.map(plt.hist, 'age')

# %%
sns.lmplot(data=iris, x='sepal_width', y='sepal_length', hue='species')

# %%
p = sns.PairGrid(iris)
p = p.map(plt.scatter)

# %%
sns.pairplot(iris)

# %%
sns.jointplot(data=iris, x='sepal_length', y='sepal_width', kind='kde')

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# ### Categorical Plot

# %%
# Strip Plot
sns.stripplot(data=iris, x='species', y='petal_length')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
# Scatter Plot
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
# Bar Chart
sns.barplot(data=titanic, x='sex', y='survived', hue='class')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
# Count Plot
sns.countplot(data=titanic, x='deck', palette='Greens_d')
# Out:
# <AxesSubplot:xlabel='deck', ylabel='count'>

# %%
# Point Plot
sns.pointplot(data=titanic, x='class', y='survived', markers=['^','o'], linestyles=['-','-o-']);

# %%
# Box plot
sns.boxplot(data=iris, orient='h')
# Out:
# <AxesSubplot:>

# %%
# Violin Plot
sns.violinplot(data=titanic, x='age', y='sex', hue='survived')
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %% [markdown]
# ### Regression Plot

# %%
sns.regplot(data=iris, x='sepal_length', y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ### Distribution Plot

# %%
sns.distplot(data['y'], kde=False, color='r');

# %% [markdown]
# ### Matrix Plot

# %%
sns.heatmap(iris.corr(), annot=True);
